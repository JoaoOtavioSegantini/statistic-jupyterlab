# %%
from numpy.random import normal

# %%
import plotly.figure_factory as ff

# %%
fig = ff.create_distplot([normal(loc = 0, scale = 1, size = 500000)],['curva normal'], show_rug= False, bin_size=2, show_hist = False)

fig.update_layout(title_text='Normal Padrão')
